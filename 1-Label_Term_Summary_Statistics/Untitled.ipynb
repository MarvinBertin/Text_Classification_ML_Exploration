# %% [markdown]
# ## Import Python Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# %load_ext autoreload

# %% [markdown]
# ## Import Utilities Class

# %%
# %autoreload 2
from utils.data_loader import DataLoader
from utils.term_frequency_helper import TermFrequency
from utils.data_frame_helper import DataFrameHelper
from utils.ZipfsLaw_helper import ZipfsLawHelper

# %% [markdown]
# ## Load Data

# %%
loader = DataLoader()
content = loader.load_data("../Data/trainingdata.txt")
# Out:
# Number of Sentences:  5485

# %% [markdown]
# # Load Data

# %%
# List topic labels for sentences.
label_names = np.array(["A", "B", "C", "D", "E", "F", "G", "H"])
df = loader.get_data_frame(content, label_names)
df_helper = DataFrameHelper(df, label_names)

# %%
df_helper.df.head()
# Out:
#   Labels                                               Text
# 0      A  champion products ch approves stock split cham...
# 1      B  computer terminal systems cpml completes sale ...
# 2      A  cobanco inc cbco year net shr cts vs dlrs net ...
# 3      A  am international inc am nd qtr jan oper shr lo...
# 4      A  brown forman inc bfd th qtr net shr one dlr vs...

# %% [markdown]
# ## Vectorize Dataset into Document-Term Frequency Matrix

# %%
min_df = 1

tf = TermFrequency(label_names, min_df = min_df)
tf.vectorize_corpus(df_helper.corpus_matrix)

# %% [markdown]
# ## Plot Count Frequencies of All the Term in the Corpus

# %%
ZipfsLaw = ZipfsLawHelper(tf.X)
ZipfsLaw.plot_corpus_term_freq()

# %% [markdown]
# ## Plot Power Law Distribution of Corpus

# %%
ZipfsLaw.plot_Zipfs_Law()
# Out:
# According to Zipfs law 1.11 should be close to 1.00
